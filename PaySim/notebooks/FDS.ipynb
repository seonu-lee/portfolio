# %% [markdown]
# ## **FDS**
#
# -> 머신러닝 및 AI 기반 탐지 (이상 탐지): 방대한 양의 과거 데이터를 학습하여 정상적인 사용자의 행동 패턴을 파악합니다. 이 학습된 패턴에서 크게 벗어나는 거래나 활동을 이상 거래로 분류합니다.
#
# -> 사회 연결망 분석 (Social Network Analysis): 거래 관계의 구조적 특성을 분석하여 숨겨진 사기 패턴이나 사기꾼들의 네트워크를 발견하는 데 사용됩니다.
#
# -> 통계적 데이터 분석: 데이터 내의 통계적 이상치를 식별하는 전통적인 방법입니다.
